# %%
import pandas as pd
import matplotlib.pyplot as plt

from datasets import load_dataset
# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#data Cleanup...
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name = "Job_Index"

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa = df[df["company_name"] == "United States"]
df_usa.reset_index(inplace= True)
df_usa
# Out:
#    Job_Index job_title_short                     job_title   job_location  \
# 0      38720  Data Scientist  Data Scientist Summer Intern     Dallas, TX
# 1      44907    Data Analyst                  Data Analyst     Dallas, TX
# 2     652496   Data Engineer                 Data Engineer  United States
# 3     655300   Data Engineer                 Data Engineer  United States
#
#             job_via job_schedule_type  job_work_from_home  \
# 0  via ZipRecruiter        Internship               False
# 1  via ZipRecruiter         Full-time               False
# 2         via BeBee         Full-time               False
# 3         via BeBee         Full-time               False
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0     Texas, United States 2023-03-25 06:05:06                  False
# 1     Texas, United States 2023-03-23 06:02:38                  False
# 2     Texas, United States 2023-09-30 10:06:53                  False
# 3  New York, United States 2023-11-03 10:04:28                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                 False  United States        None              NaN
# 2                 False  United States        None              NaN
# 3                 False  United States        None              NaN
#
#    salary_hour_avg   company_name  \
# 0              NaN  United States
# 1              NaN  United States
# 2              NaN  United States
# 3              NaN  United States
#
#                                           job_skills  \
# 0  ['python', 'sql', 'r', 'sas', 'sas', 'pandas',...
# 1  ['sql', 'javascript', 'python', 'r', 'oracle',...
# 2  ['python', 'hadoop', 'spark', 'kafka', 'pyspark']
# 3  ['scala', 'sql', 'nosql', 'bigquery', 'spark',...
#
#                                      job_type_skills
# 0  {'analyst_tools': ['sas', 'word', 'excel'], 'l...
# 1  {'analyst_tools': ['tableau', 'power bi'], 'cl...
# 2  {'libraries': ['hadoop', 'spark', 'kafka', 'py...
# 3  {'analyst_tools': ['looker'], 'cloud': ['bigqu...

# %%
df_usa.set_index('Job_Index')
# Out:
#           job_title_short                     job_title   job_location  \
# Job_Index
# 38720      Data Scientist  Data Scientist Summer Intern     Dallas, TX
# 44907        Data Analyst                  Data Analyst     Dallas, TX
# 652496      Data Engineer                 Data Engineer  United States
# 655300      Data Engineer                 Data Engineer  United States
#
#                     job_via job_schedule_type  job_work_from_home  \
# Job_Index
# 38720      via ZipRecruiter        Internship               False
# 44907      via ZipRecruiter         Full-time               False
# 652496            via BeBee         Full-time               False
# 655300            via BeBee         Full-time               False
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# Job_Index
# 38720         Texas, United States 2023-03-25 06:05:06                  False
# 44907         Texas, United States 2023-03-23 06:02:38                  False
# 652496        Texas, United States 2023-09-30 10:06:53                  False
# 655300     New York, United States 2023-11-03 10:04:28                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# Job_Index
# 38720                     False  United States        None              NaN
# 44907                     False  United States        None              NaN
# 652496                    False  United States        None              NaN
# 655300                    False  United States        None              NaN
#
#            salary_hour_avg   company_name  \
# Job_Index
# 38720                  NaN  United States
# 44907                  NaN  United States
# 652496                 NaN  United States
# 655300                 NaN  United States
#
#                                                   job_skills  \
# Job_Index
# 38720      ['python', 'sql', 'r', 'sas', 'sas', 'pandas',...
# 44907      ['sql', 'javascript', 'python', 'r', 'oracle',...
# 652496     ['python', 'hadoop', 'spark', 'kafka', 'pyspark']
# 655300     ['scala', 'sql', 'nosql', 'bigquery', 'spark',...
#
#                                              job_type_skills
# Job_Index
# 38720      {'analyst_tools': ['sas', 'word', 'excel'], 'l...
# 44907      {'analyst_tools': ['tableau', 'power bi'], 'cl...
# 652496     {'libraries': ['hadoop', 'spark', 'kafka', 'py...
# 655300     {'analyst_tools': ['looker'], 'cloud': ['bigqu...
